# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose, STL
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.gofplots import qqplot
from statsmodels.tsa.stattools import adfuller
from tqdm import tqdm_notebook
from itertools import product
from typing import Union

import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ### SARIMAX: using exogenous variables

# %%
macro_econ_data = sm.datasets.macrodata.load_pandas().data
macro_econ_data
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# ..      ...      ...        ...       ...       ...       ...      ...
# 198  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 199  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 200  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 201  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 202  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
#          cpi      m1  tbilrate  unemp      pop  infl  realint
# 0     28.980   139.7      2.82    5.8  177.146  0.00     0.00
# 1     29.150   141.7      3.08    5.1  177.830  2.34     0.74
# 2     29.350   140.5      3.82    5.3  178.657  2.74     1.09
# 3     29.370   140.0      4.33    5.6  179.386  0.27     4.06
# 4     29.540   139.6      3.50    5.2  180.007  2.31     1.19
# ..       ...     ...       ...    ...      ...   ...      ...
# 198  216.889  1474.7      1.17    6.0  305.270 -3.16     4.33
# 199  212.174  1576.5      0.12    6.9  305.952 -8.79     8.91
# 200  212.671  1592.8      0.22    8.1  306.547  0.94    -0.71
# 201  214.469  1653.6      0.18    9.2  307.226  3.37    -3.19
# 202  216.385  1673.9      0.12    9.6  308.013  3.56    -3.44
#
# [203 rows x 14 columns]

# %%
fig, ax = plt.subplots()

ax.plot(macro_econ_data['realgdp'])
ax.set_xlabel('Date')
ax.set_ylabel('Real GDP (k$)')

plt.xticks(np.arange(0, 208, 16), np.arange(1959, 2010, 4))

fig.autofmt_xdate()
plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, dpi=300, figsize=(11,6))

for i, ax in enumerate(axes.flatten()[:6]):
    data = macro_econ_data[macro_econ_data.columns[i+2]]
    
    ax.plot(data, color='black', linewidth=1)
    ax.set_title(macro_econ_data.columns[i+2])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines['top'].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.setp(axes, xticks=np.arange(0, 208, 8), xticklabels=np.arange(1959, 2010, 2))
fig.autofmt_xdate()
plt.tight_layout()

# %% [markdown]
# selecting which is the target of the forecast and which are the exogenous variables

# %%
target = macro_econ_data['realgdp']
exog = macro_econ_data[['realcons', 'realinv', 'realgovt', 'realdpi', 'cpi']]

# %% [markdown]
# ADF test in the target time series

# %%
ad_fuller_result = adfuller(target)

print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: 1.7504627967647095
# p-value: 0.9982455372335032

# %%
target_diff = target.diff()

ad_fuller_result = adfuller(target_diff[1:])

print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -6.305695561658102
# p-value: 3.327882187668259e-08

# %% [markdown]
# d=2

# %% [markdown]
# create function optimize sarima adding exog values to get the AIC for each model

# %%
def optimize_SARIMAX(endog: Union[pd.Series, list], exog: Union[pd.Series, list], order_list: list, d: int, D: int, s: int) -> pd.DataFrame:
    
    results = []
    
    for order in tqdm_notebook(order_list):
        try: 
            model = SARIMAX(
                endog,
                exog,
                order=(order[0], d, order[1]),
                seasonal_order=(order[2], D, order[3], s),
                simple_differencing=False).fit(disp=False)
        except:
            continue
            
        aic = model.aic
        results.append([order, aic])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q,P,Q)', 'AIC']
    
    #Sort in ascending order, lower AIC is better
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    
    return result_df

# %%
p = range(0, 4, 1)
d = 1
q = range(0, 4, 1)
P = range(0, 4, 1)
D = 0
Q = range(0, 4, 1)
s = 4

parameters = product(p, q, P, Q)
parameters_list = list(parameters)

# %%
target_train = target[:200]
exog_train = exog[:200]

result_df = optimize_SARIMAX(target_train, exog_train, parameters_list, d, D, s)
result_df
# Out:
#   0%|          | 0/256 [00:00<?, ?it/s]
#         (p,q,P,Q)          AIC
# 0    (3, 3, 0, 0)  1742.840942
# 1    (3, 3, 1, 0)  1744.964600
# 2    (3, 3, 0, 1)  1744.996594
# 3    (2, 2, 0, 0)  1745.432304
# 4    (2, 2, 0, 1)  1745.806696
# ..            ...          ...
# 251  (0, 2, 0, 0)  1761.579044
# 252  (0, 3, 0, 0)  1762.317095
# 253  (0, 0, 0, 0)  1764.754980
# 254  (1, 0, 0, 0)  1765.379412
# 255  (0, 1, 0, 0)  1765.813488
#
# [256 rows x 2 columns]

# %% [markdown]
# m=4 as is quarterly data

# %%
best_model = SARIMAX(target_train, exog_train, order=(3,1,3), seasonal_order=(0,0,0,4), simple_differencing=False)
best_model_fit = best_model.fit(disp=False)

print(best_model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                realgdp   No. Observations:                  200
# Model:               SARIMAX(3, 1, 3)   Log Likelihood                -859.420
# Date:                Sun, 20 Oct 2024   AIC                           1742.841
# Time:                        20:37:44   BIC                           1782.361
# Sample:                             0   HQIC                          1758.836
#                                 - 200
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# realcons       0.9663      0.045     21.625      0.000       0.879       1.054
# realinv        1.0136      0.033     30.862      0.000       0.949       1.078
# realgovt       0.7280      0.127      5.737      0.000       0.479       0.977
# realdpi        0.0092      0.025      0.372      0.710      -0.039       0.058
# cpi            5.8672      1.311      4.476      0.000       3.298       8.436
# ar.L1          1.0658      0.395      2.697      0.007       0.291       1.840
# ar.L2          0.4907      0.696      0.706      0.480      -0.872       1.854
# ar.L3         -0.6740      0.334     -2.016      0.044      -1.329      -0.019
# ma.L1         -1.1037      0.427     -2.586      0.010      -1.940      -0.267
# ma.L2         -0.3205      0.761     -0.421      0.674      -1.812       1.171
# ma.L3          0.6461      0.400      1.614      0.106      -0.138       1.430
# sigma2       329.6156     30.495     10.809      0.000     269.847     389.384
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                13.41
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.56   Skew:                             0.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
best_model_fit.plot_diagnostics(figsize=(10,8));

# %%
residuals = best_model_fit.resid

lbvalue, pvalue = acorr_ljungbox(residuals, np.arange(1, 11, 1))

print(pvalue)
# Out:
# lb_pvalue

# %%
def recursive_forecast(endog: Union[pd.Series, list], exog: Union[pd.Series, list], train_len: int, horizon: int, window: int, method: str) -> list:
    
    total_len = train_len + horizon

    if method == 'last':
        pred_last_value = []
        
        for i in range(train_len, total_len, window):
            last_value = endog[:i].iloc[-1]
            pred_last_value.extend(last_value for _ in range(window))
            
        return pred_last_value
    
    elif method == 'SARIMAX':
        pred_SARIMAX = []
        
        for i in range(train_len, total_len, window):
            model = SARIMAX(endog[:i], exog[:i], order=(3,1,3), seasonal_order=(0,0,0,4), simple_differencing=False)
            res = model.fit(disp=False)
            predictions = res.get_prediction(exog=exog)
            oos_pred = predictions.predicted_mean.iloc[-window:]
            pred_SARIMAX.extend(oos_pred)
            
        return pred_SARIMAX

# %%
target_train = target[:196]
target_test = target[196:]

pred_df = pd.DataFrame({'actual': target_test})

TRAIN_LEN = len(target_train)
HORIZON = len(target_test)
WINDOW = 1

pred_last_value = recursive_forecast(target, exog, TRAIN_LEN, HORIZON, WINDOW, 'last')
pred_SARIMAX = recursive_forecast(target, exog, TRAIN_LEN, HORIZON, WINDOW, 'SARIMAX')

pred_df['pred_last_value'] = pred_last_value
pred_df['pred_SARIMAX'] = pred_SARIMAX

pred_df
# Out:
#         actual  pred_last_value  pred_SARIMAX
# 196  13366.865        13391.249  13344.064769
# 197  13415.266        13366.865  13373.510371
# 198  13324.600        13415.266  13378.828416
# 199  13141.920        13324.600  13327.778290
# 200  12925.410        13141.920  13133.833069
# 201  12901.504        12925.410  12887.024689
# 202  12990.341        12901.504  12873.797047

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mape_last = mape(pred_df.actual, pred_df.pred_last_value)
mape_SARIMAX = mape(pred_df.actual, pred_df.pred_SARIMAX)

print(mape_last, mape_SARIMAX)
# Out:
# 0.736849498653785 0.7035630924311178

# %%
fig, ax = plt.subplots()

x = ['naive last value', 'SARIMAX']
y = [mape_last, mape_SARIMAX]

ax.bar(x, y, width=0.4)
ax.set_xlabel('Models')
ax.set_ylabel('MAPE (%)')
ax.set_ylim(0, 1)

for index, value in enumerate(y):
    plt.text(x=index, y=value + 0.05, s=str(round(value,2)), ha='center')

plt.tight_layout()

# %% [markdown]
# ### SARIMAX exercise.
# 1. use all exogenous variables
# 2. produce the forecast for the lasts 7 timesteps
# 3. check if the MAPE is better now

# %%
macro_econ_data = sm.datasets.macrodata.load_pandas().data
macro_econ_data
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# ..      ...      ...        ...       ...       ...       ...      ...
# 198  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 199  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 200  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 201  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 202  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
#          cpi      m1  tbilrate  unemp      pop  infl  realint
# 0     28.980   139.7      2.82    5.8  177.146  0.00     0.00
# 1     29.150   141.7      3.08    5.1  177.830  2.34     0.74
# 2     29.350   140.5      3.82    5.3  178.657  2.74     1.09
# 3     29.370   140.0      4.33    5.6  179.386  0.27     4.06
# 4     29.540   139.6      3.50    5.2  180.007  2.31     1.19
# ..       ...     ...       ...    ...      ...   ...      ...
# 198  216.889  1474.7      1.17    6.0  305.270 -3.16     4.33
# 199  212.174  1576.5      0.12    6.9  305.952 -8.79     8.91
# 200  212.671  1592.8      0.22    8.1  306.547  0.94    -0.71
# 201  214.469  1653.6      0.18    9.2  307.226  3.37    -3.19
# 202  216.385  1673.9      0.12    9.6  308.013  3.56    -3.44
#
# [203 rows x 14 columns]

# %%
target = macro_econ_data['realgdp']
exog = macro_econ_data[['realcons', 'realinv', 'realgovt', 'realdpi', 'cpi', 
                        'm1', 'tbilrate', 'unemp', 'pop', 'infl', 'realint']]

# %%
ad_fuller_result = adfuller(target)

print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: 1.7504627967647095
# p-value: 0.9982455372335032

# %%
target_diff = target.diff()

ad_fuller_result = adfuller(target_diff[1:])

print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -6.305695561658102
# p-value: 3.327882187668259e-08

# %% [markdown]
# The series is not stationary. Therefore d=1/D=0, also since we have quarterly data then m=4
# .

# %%
def optimize_SARIMAX(endog: Union[pd.Series, list], exog: Union[pd.Series, list], order_list: list, d: int, D: int, s: int) -> pd.DataFrame:
    
    results = []
    
    for order in tqdm_notebook(order_list):
        try: 
            model = SARIMAX(
                endog,
                exog,
                order=(order[0], d, order[1]),
                seasonal_order=(order[2], D, order[3], s),
                simple_differencing=False).fit(disp=False)
        except:
            continue
            
        aic = model.aic
        results.append([order, aic])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q,P,Q)', 'AIC']
    
    #Sort in ascending order, lower AIC is better
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    
    return result_df

# %%
target_train = target[:200]
exog_train = exog[:200]

# %%
p = range(0, 4, 1)
d = 1
q = range(0, 4, 1)
P = range(0, 4, 1)
D = 0
Q = range(0, 4, 1)
s = 4

parameters = product(p, q, P, Q)
parameters_list = list(parameters)

# %%
result_df = optimize_SARIMAX(target_train, exog_train, parameters_list, d, D, s)
result_df
# Out:
#   0%|          | 0/256 [00:00<?, ?it/s]
#         (p,q,P,Q)          AIC
# 0    (2, 2, 1, 0)  1757.072844
# 1    (3, 3, 0, 0)  1757.859726
# 2    (2, 2, 0, 2)  1758.324470
# 3    (2, 2, 0, 0)  1759.104011
# 4    (2, 2, 2, 0)  1759.507093
# ..            ...          ...
# 251  (3, 2, 2, 1)  1776.806694
# 252  (3, 2, 1, 3)  1776.867105
# 253  (3, 2, 1, 1)  1776.944861
# 254  (3, 2, 1, 2)  1778.132474
# 255  (3, 2, 3, 1)  1778.371639
#
# [256 rows x 2 columns]

# %%
best_model = SARIMAX(target_train, exog_train, order=(2,1,2), seasonal_order=(1,0,0,4), simple_differencing=False)
best_model_fit = best_model.fit(disp=False)

print(best_model_fit.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                            realgdp   No. Observations:                  200
# Model:             SARIMAX(2, 1, 2)x(1, 0, [], 4)   Log Likelihood                -861.536
# Date:                            Sun, 20 Oct 2024   AIC                           1757.073
# Time:                                    20:46:47   BIC                           1813.059
# Sample:                                         0   HQIC                          1779.732
#                                             - 200
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# realcons       0.9570      0.054     17.643      0.000       0.851       1.063
# realinv        0.9957      0.042     23.570      0.000       0.913       1.079
# realgovt       0.7328      0.139      5.265      0.000       0.460       1.006
# realdpi        0.0108      0.024      0.448      0.654      -0.037       0.058
# cpi            5.3578      2.067      2.592      0.010       1.306       9.410
# m1         -5.245e-06      0.160  -3.29e-05      1.000      -0.313       0.313
# tbilrate      -3.7353     24.002     -0.156      0.876     -50.777      43.307
# unemp         -7.9247      5.739     -1.381      0.167     -19.173       3.323
# pop            5.7680      7.572      0.762      0.446      -9.073      20.609
# infl          -0.6116     23.888     -0.026      0.980     -47.432      46.209
# realint       -0.4712     23.844     -0.020      0.984     -47.204      46.261
# ar.L1          1.8100      0.054     33.522      0.000       1.704       1.916
# ar.L2         -0.8835      0.056    -15.715      0.000      -0.994      -0.773
# ma.L1         -1.8078      0.041    -44.043      0.000      -1.888      -1.727
# ma.L2          0.9380      0.038     24.785      0.000       0.864       1.012
# ar.S.L4        0.0865      0.069      1.251      0.211      -0.049       0.222
# sigma2       325.9573     30.091     10.832      0.000     266.979     384.935
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.18   Jarque-Bera (JB):                14.16
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.84   Skew:                             0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
best_model_fit.plot_diagnostics(figsize=(10,8));

# %%
residuals = best_model_fit.resid

lbvalue, pvalue = acorr_ljungbox(residuals, np.arange(1, 11, 1))

print(pvalue)
# Out:
# lb_pvalue

# %%
def recursive_forecast(endog: Union[pd.Series, list], exog: Union[pd.Series, list], train_len: int, horizon: int, window: int, method: str) -> list:
    
    total_len = train_len + horizon

    if method == 'last':
        pred_last_value = []
        
        for i in range(train_len, total_len, window):
            last_value = endog[:i].iloc[-1]
            pred_last_value.extend(last_value for _ in range(window))
            
        return pred_last_value
    
    elif method == 'SARIMAX':
        pred_SARIMAX = []
        
        for i in range(train_len, total_len, window):
            model = SARIMAX(endog[:i], exog[:i], order=(2,1,2), seasonal_order=(1,0,0,4), simple_differencing=False)
            res = model.fit(disp=False)
            predictions = res.get_prediction(exog=exog)
            oos_pred = predictions.predicted_mean.iloc[-window:]
            pred_SARIMAX.extend(oos_pred)
            
        return pred_SARIMAX

# %%
target_train = target[:196]
target_test = target[196:]

pred_df = pd.DataFrame({'actual': target_test})

TRAIN_LEN = len(target_train)
HORIZON = len(target_test)
WINDOW = 1

pred_last_value = recursive_forecast(target, exog, TRAIN_LEN, HORIZON, WINDOW, 'last')
pred_SARIMAX = recursive_forecast(target, exog, TRAIN_LEN, HORIZON, WINDOW, 'SARIMAX')

pred_df['pred_last_value'] = pred_last_value
pred_df['pred_SARIMAX'] = pred_SARIMAX

pred_df
# Out:
#         actual  pred_last_value  pred_SARIMAX
# 196  13366.865        13391.249  13345.321953
# 197  13415.266        13366.865  13375.017588
# 198  13324.600        13415.266  13369.525863
# 199  13141.920        13324.600  13331.758458
# 200  12925.410        13141.920  13135.742758
# 201  12901.504        12925.410  12887.629314
# 202  12990.341        12901.504  12867.284876

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mape_last = mape(pred_df.actual, pred_df.pred_last_value)
mape_SARIMAX = mape(pred_df.actual, pred_df.pred_SARIMAX)

print(mape_last, mape_SARIMAX)
# Out:
# 0.736849498653785 0.7035702274560379

# %%
fig, ax = plt.subplots()

x = ['naive last value', 'SARIMAX']
y = [mape_last, mape_SARIMAX]

ax.bar(x, y, width=0.4)
ax.set_xlabel('Models')
ax.set_ylabel('MAPE (%)')
ax.set_ylim(0, 1)

for index, value in enumerate(y):
    plt.text(x=index, y=value + 0.05, s=str(round(value,2)), ha='center')

plt.tight_layout()

# %% [markdown]
# with few exogenous we had a MAPE of 0.7039%. Using all exgogenous variables, we achieved a MAPE of 0.7019%. It is only very slightly better.
